# %%
# %matplotlib inline

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Global_Mobility_Report.csv')
# Out:
# /Users/asifali/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
#        'metro_area', 'iso_3166_2_code', 'census_fips_code', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %%
df.sub_region_2.value_counts()
# Out:
# Washington County    8832
# Jefferson County     7327
# Franklin County      6906
# Jackson County       6315
# Lincoln County       6019
#                      ...
# Wirt County             2
# Wheeler County          1
# Real County             1
# Nome                    1
# Lyman County            1
# Name: sub_region_2, Length: 9915, dtype: int64

# %%
df.sub_region_1.value_counts()
# Out:
# State of São Paulo            115684
# State of Minas Gerais          79593
# Texas                          62201
# State of Rio Grande do Sul     47702
# State of Paraná                46746
#                                ...
# Wajir County                       2
# Salacgrīva Municipality            2
# Krimulda Municipality              1
# Centre-Nord Region                 1
# Savanes Region                     1
# Name: sub_region_1, Length: 1860, dtype: int64

# %%
df2 = df[['date', 'country_region', 'sub_region_1', 'sub_region_2','retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline']]

# %%
df2.count()
# Out:
# date                                                  3864588
# country_region                                        3864588
# sub_region_1                                          3798345
# sub_region_2                                          3218039
# retail_and_recreation_percent_change_from_baseline    2436492
# grocery_and_pharmacy_percent_change_from_baseline     2353081
# dtype: int64

# %%
df3 = df2.dropna()

# %%
df3.count()
# Out:
# date                                                  1680284
# country_region                                        1680284
# sub_region_1                                          1680284
# sub_region_2                                          1680284
# retail_and_recreation_percent_change_from_baseline    1680284
# grocery_and_pharmacy_percent_change_from_baseline     1680284
# dtype: int64

# %%
df3.describe()
# Out:
#        retail_and_recreation_percent_change_from_baseline  \
# count                                       1.680284e+06
# mean                                       -2.286069e+01
# std                                         2.823298e+01
# min                                        -1.000000e+02
# 25%                                        -4.100000e+01
# 50%                                        -1.800000e+01
# 75%                                        -3.000000e+00
# max                                         5.450000e+02
#
#        grocery_and_pharmacy_percent_change_from_baseline
# count                                       1.680284e+06
# mean                                       -1.820421e+00
# std                                         2.475976e+01
# min                                        -1.000000e+02
# 25%                                        -1.200000e+01
# 50%                                        -1.000000e+00
# 75%                                         1.000000e+01
# max                                         3.970000e+02

# %%
df3.head()
# Out:
#             date country_region  sub_region_1 sub_region_2  \
# 6829  2020-02-15      Argentina  Buenos Aires     Comuna 1
# 6830  2020-02-16      Argentina  Buenos Aires     Comuna 1
# 6831  2020-02-17      Argentina  Buenos Aires     Comuna 1
# 6832  2020-02-18      Argentina  Buenos Aires     Comuna 1
# 6833  2020-02-19      Argentina  Buenos Aires     Comuna 1
#
#       retail_and_recreation_percent_change_from_baseline  \
# 6829                                               14.0
# 6830                                               -1.0
# 6831                                               -6.0
# 6832                                               12.0
# 6833                                                8.0
#
#       grocery_and_pharmacy_percent_change_from_baseline
# 6829                                                2.0
# 6830                                               -2.0
# 6831                                              -15.0
# 6832                                               10.0
# 6833                                                8.0

# %%
df4 = df3.set_index('date').sort_index()

# %%
df4.index.max()
# Out:
# '2021-01-12'

# %%
df4.index.min()
# Out:
# '2020-02-15'

# %%
df4.country_region.value_counts()
# Out:
# United States     472442
# Brazil            206272
# India             177523
# United Kingdom     83859
# Turkey             76964
# Argentina          73955
# Poland             73803
# Netherlands        55125
# Australia          54331
# Canada             46741
# Italy              35106
# France             31284
# Portugal           26014
# Colombia           23900
# Sweden             22770
# Czechia            21499
# Austria            19020
# Romania            18062
# Denmark            17149
# Spain              14229
# Chile              14125
# Nigeria            12627
# Slovakia           11552
# Peru               11376
# Finland            11337
# Norway              9662
# Bulgaria            9151
# Ecuador             8999
# Guatemala           6419
# Lithuania           4850
# Bolivia             4822
# Lebanon             4246
# Israel              4000
# Slovenia            3682
# Honduras            3544
# Belgium             3321
# Tanzania            2048
# Cameroon            1509
# Rwanda               859
# Mozambique           757
# Uganda               719
# Zimbabwe             631
# Name: country_region, dtype: int64

# %%
df5 = df4[(df4['country_region'] == 'United States') | (df4['country_region'] == 'India')]

# %%
df5.sort_values('country_region').head()
# Out:
#            country_region    sub_region_1 sub_region_2  \
# date
# 2020-05-01          India  Madhya Pradesh         Agar
# 2020-05-13          India    Chhattisgarh   Mahasamund
# 2020-10-23          India       Telangana     Nalgonda
# 2020-10-23          India     Maharashtra       Nanded
# 2020-05-13          India           Delhi    New Delhi
#
#             retail_and_recreation_percent_change_from_baseline  \
# date
# 2020-05-01                                              -77.0
# 2020-05-13                                              -65.0
# 2020-10-23                                                3.0
# 2020-10-23                                              -18.0
# 2020-05-13                                              -89.0
#
#             grocery_and_pharmacy_percent_change_from_baseline
# date
# 2020-05-01                                              -19.0
# 2020-05-13                                               44.0
# 2020-10-23                                               48.0
# 2020-10-23                                               40.0
# 2020-05-13                                              -70.0

# %% [markdown]
# ## India

# %%
india = df5[df5.country_region == 'India']

# %%
india.to_csv('India.csv')

# %%
ind_grp = india.groupby('sub_region_1')

ind_grp.mean().plot(grid=True,figsize = (20,7),fontsize=20, rot=45)
plt.title('Covid-19 Impact on Retail/Recreation and Grocery/Pharmacy',fontsize=25)
plt.show()

# %%
ind_grp.mean().sort_values("sub_region_1",ascending=False).plot(kind='barh',figsize = (20,10), grid=True,fontsize=20)
plt.ylabel("States")
plt.title('Covid-19 Impact on Retail/Recreation and Grocery/Pharmacy',fontsize=25)
plt.show()

# %% [markdown]
# ## United States

# %%
us = df5[df5.country_region == 'United States']

# %%
us.to_csv('US.csv')
# Out:
#            country_region sub_region_1      sub_region_2  \
# date
# 2020-03-06  United States      Alabama  Covington County
# 2020-03-30  United States      Alabama        Lee County
# 2020-02-22  United States      Alabama  Limestone County
# 2020-03-30  United States      Alabama   Lawrence County
# 2020-06-14  United States      Alabama  St. Clair County
# ...                   ...          ...               ...
# 2020-09-25  United States      Wyoming    Fremont County
# 2020-03-23  United States      Wyoming      Uinta County
# 2020-05-26  United States      Wyoming    Laramie County
# 2020-07-27  United States      Wyoming   Campbell County
# 2020-04-30  United States      Wyoming    Laramie County
#
#             retail_and_recreation_percent_change_from_baseline  \
# date
# 2020-03-06                                               17.0
# 2020-03-30                                              -41.0
# 2020-02-22                                                5.0
# 2020-03-30                                              -24.0
# 2020-06-14                                                7.0
# ...                                                       ...
# 2020-09-25                                                0.0
# 2020-03-23                                              -13.0
# 2020-05-26                                               -5.0
# 2020-07-27                                                4.0
# 2020-04-30                                              -22.0
#
#             grocery_and_pharmacy_percent_change_from_baseline
# date
# 2020-03-06                                                4.0
# 2020-03-30                                              -18.0
# 2020-02-22                                                5.0
# 2020-03-30                                               -4.0
# 2020-06-14                                               10.0
# ...                                                       ...
# 2020-09-25                                               12.0
# 2020-03-23                                               26.0
# 2020-05-26                                                8.0
# 2020-07-27                                                9.0
# 2020-04-30                                               -2.0
#
# [472442 rows x 5 columns]

# %%
us_grp = us.groupby('sub_region_1')

us_grp.mean().plot(grid=True,figsize = (20,7), fontsize = 20, rot=45)
plt.title('Covid-19 Impact on Retail/Recreation and Grocery/Pharmacy',fontsize=25)
plt.show()

# %%
us_grp.mean().sort_values("sub_region_1",ascending=False).plot(kind='barh',grid=True,figsize = (20,15), fontsize = 15)
plt.title('Covid-19 Impact on Retail/Recreation and Grocery/Pharmacy',fontsize=25)
plt.ylabel("States")
plt.show()

# %%
dated_us = us.sort_index()

# %%
dated_us.head()
# Out:
#            country_region sub_region_1        sub_region_2  \
# date
# 2020-02-15  United States         Iowa     Buchanan County
# 2020-02-15  United States         Iowa  Buena Vista County
# 2020-02-15  United States         Iowa      Carroll County
# 2020-02-15  United States         Iowa         Cass County
# 2020-02-15  United States         Iowa        Cedar County
#
#             retail_and_recreation_percent_change_from_baseline  \
# date
# 2020-02-15                                                2.0
# 2020-02-15                                                9.0
# 2020-02-15                                                1.0
# 2020-02-15                                               10.0
# 2020-02-15                                               -2.0
#
#             grocery_and_pharmacy_percent_change_from_baseline
# date
# 2020-02-15                                               -4.0
# 2020-02-15                                                7.0
# 2020-02-15                                               -6.0
# 2020-02-15                                               -1.0
# 2020-02-15                                               -3.0
